# %% [markdown]
# <a href="https://colab.research.google.com/github/pratikshakirolkar/Final-Project/blob/main/Basic_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install bar_chart_race
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 KB 13.8 MB/s eta 0:00:00
# ...

# %%
#Importing_Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as py
import plotly.offline

# %%
# date and time
import datetime as date

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)
import plotly as py
import plotly.graph_objs as go
from plotly.offline import iplot, init_notebook_mode
import bar_chart_race as bcr

# %%
# Import dataset
data=pd.read_csv('/content/Data 1 MAJOR.csv')

# %%
data.head()
# Out:
#        Date  User1  User2  User3  User4  User5  User6  User7  User8  User9  \
# 0  01-04-21     73    273     93    419    176    118     27      6     43
# 1  01-05-21    100    206     88    453    197    136     45     10     48
# 2  01-06-21     44    182     92    484    178    127     16     13     55
# 3  01-07-21     61    164     67     43    139    255      1      9     54
# 4  01-08-21     71    197     72     16    147    121     77      7     47
#
#    User10  User11  User12  User13  User14  User15  User16  User17  User18  \
# 0      79     169     150     183     701      95      51     174     133
# 1      70     169     140     159     658     108      55     176     173
# 2     187     175     132     146     672     100      56     173     142
# 3      81     151     147     109     586      98      47     137      92
# 4     113     154     147      82     603      96      46     155      85
#
# ...

# %%
# copy of Data ser
data_copy=data.copy()

# %%
# Rename date
data.rename(columns={'Unnamed: 0':'date'}, inplace=True)
# change object into date and time formet 
data['Date']=pd.to_datetime(data['Date'])
data_copy=data.copy()

# %%
# Reset index value 
data.set_index('Date',inplace=True)

# %%
# checking null values
data.isnull().sum()
# Out:
# User1      0
# User2      0
# User3      0
# User4      0
# User5      0
# User6      0
# User7      0
# User8      0
# User9      0
# User10     0
# User11     0
# User12     0
# User13     0
# User14     0
# User15     0
# User16     0
# User17     0
# User18     0
# User19     0
# User20     0
# User21     0
# User22     0
# User23     0
# User24     0
# User25     0
# User26     0
# User27     0
# User28     0
# User29     0
# User30     0
# User31     0
# User32     0
# User33     0
# User34     0
# User35     0
# User36     0
# User37     0
# User38     0
# User39     0
# User40     0
# User41     0
# User42     0
# User43     0
# User44     0
# User45     0
# User46     0
# User47     0
# User48     0
# User49     0
# User50     0
# User51     0
# User52     0
# User53     0
# User54     0
# User55     0
# User56     0
# User57     0
# User58     0
# User59     0
# User60     0
# User61     0
# User62     0
# User63     0
# User64     0
# User65     0
# User66     0
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.filters.hp_filter import hpfilter
import warnings
warnings.filterwarnings("ignore")
import altair as alt
# %matplotlib inline

# %%
# Import dataset
long_data=pd.read_csv('/content/UserData.csv')

# %%
long_data.head()
# Out:
#                   Date  Year    Month  Day    Users  Sum of Value
# 0  2021-01-04 00:00:00  2021  January    4    User1            73
# 1  2021-01-04 00:00:00  2021  January    4   User10            79
# 2  2021-01-04 00:00:00  2021  January    4  User100           242
# 3  2021-01-04 00:00:00  2021  January    4  User101           164
# 4  2021-01-04 00:00:00  2021  January    4  User102           274

# %%
# print("***************2022****************")
usage2022=dict()
for i in (long_data.Users.unique()):
    a=long_data[(long_data["Users"]==i)&(long_data["Year"]==2022)]
    b=a.Users.sum()
    usage2022.update({i:b})
# print(usage2021)
# print("***************2021****************")
usage2021=dict()
for i in (long_data.Users.unique()):
    a=long_data[(long_data["Users"]==i)&(long_data["Year"]==2021)]
    b=a.Users.sum()
    usage2021.update({i:b})
# print(usage2021)

# %%
table3=pd.DataFrame.from_dict(usage2021,orient="index")
table4=pd.DataFrame.from_dict(usage2022,orient="index")

# %%
table3.rename(columns={0:'toat usage in 2021'},inplace=True)
table4.rename(columns={0:'toat usage in 2022'},inplace=True)

# %%
table3.sort_values(by=['toat usage in 2021'],ascending=False,inplace=True)
table4.sort_values(by=['toat usage in 2022'],ascending=False,inplace=True)

# %%
y2k_pop = long_data.query('Year == 2021')

# %%
alt.Chart(y2k_pop).mark_bar().encode(
    x='Sum of Value',
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(y2k_pop).mark_bar().encode(
    x='Sum of Value',
    y='Users:O'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_bar().encode(
    x=alt.X('Sum of Value', axis=alt.Axis(title='Sum of Value')),
    y=alt.Y('Users',
        sort=alt.EncodingSortField(field='Sum of Value', order='ascending', op='sum'),
        axis=alt.Axis(title='Title')
    ),
    color=alt.Color('title:N')
)
# Out:
# alt.Chart(...)

# %%
chart = alt.Chart(long_data).transform_filter(
    "datum.year == 2021"
).transform_calculate(
    "Users", "datum.sex == 1 ? 'User1' : 'User2'"
).encode(
    color=alt.Color('sex:N', scale=alt.Scale(range=["#e377c2","#1f77b4"]))
)

# %%
month=["jan","feb",'march',"april","may","june","july","aug","sep","oct","nov","dec"]
